# %%
import os, glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import imageio
import geopandas as gpd
from IPython.display import Image, display
import tensorflow as tf
from tensorflow.keras import layers, callbacks, backend, Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from plot_keras_history import show_history, plot_history
import matplotlib.pyplot as plt
from keras.preprocessing import image
# Out:
# 2023-05-29 17:09:15.707321: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df=pd.read_csv("./methane_224_data/smallsize224_all.csv")

# %%
df.shape
# Out:
# (86599, 10)

# %%
df.Type.value_counts()
# Out:
# Type
# Negative                                        34869
# CAFOs                                           25073
# WWTreatment                                     14441
# Landfills                                        4053
# RefineriesAndTerminals                           3961
# ProcessingPlants                                 1975
# Mines                                            1816
# WWTreatment-RefineriesAndTerminals                114
# WWTreatment-Landfills                              76
# Mines-Landfills                                    58
# RefineriesAndTerminals-ProcessingPlants            47
# RefineriesAndTerminals-Landfills                   31
# RefineriesAndTerminals-WWTreatment                 17
# CAFOs-WWTreatment                                  16
# WWTreatment-ProcessingPlants                       13
# WWTreatment-Mines                                   8
# CAFOs-Landfills                                     7
# ProcessingPlants-Landfills                          6
# WWTreatment-RefineriesAndTerminals-Landfills        5
# Landfills-WWTreatment                               4
# Mines-ProcessingPlants                              4
# Landfills-RefineriesAndTerminals                    2
# Mines-RefineriesAndTerminals                        2
# Roundabout                                          1
# Name: count, dtype: int64

# %%
df = df.dropna()

# %%
df.head(2)
# Out:
#    Unnamed: 0   Latitude  Longitude      Type
# 0           0  43.948271 -93.649496     CAFOs  \
# 1           1  43.004434 -78.208900  Negative
#
#                             Source
# 0  MinnesotaPollutionControlAgency  \
# 1                       Aeroplanes
#
#                                         Image_Folder
# 0               train_images/43.94827109_-93.6494963  \
# 1  train_images/43.00443446102501_-78.20890003579709
#
#                                             geometry dataset
# 0  POLYGON ((-93.64626236497716 43.95060750304138...   train  \
# 1  POLYGON ((-78.20566610077425 43.00680791855935...   train
#
#                   Image_Folder_long_lat
# 0               43.94827109_-93.6494963  \
# 1  43.00443446102501_-78.20890003579709
#
#                                              img_dir
# 0  F:\\CNOOC_testing\\Methane_dataset\\METHANE_PR...
# 1  F:\\CNOOC_testing\\Methane_dataset\\METHANE_PR...

# %%
df.Type = df.Type.astype(str)

# %%
root = './methane_224_data/smallsize224/'

# %%
df['new_path'] = df.img_dir.apply(lambda x: x.replace('F:\\\\CNOOC_testing\\\\Methane_dataset\\\\METHANE_PROJECT\\\\smallsize224\\\\', root)\
    .replace('F:\\\\CNOOC_testing\\\\Methane_dataset\\\\METHANE_PROJECT\\\\smallsize224_val\\\\', root)\
    .replace('F:\\\\CNOOC_testing\\\\Methane_dataset\\\\METHANE_PROJECT\\\\smallsize224_test\\\\', root)\
    .replace("\\\\", "/").replace("\\", "/"))

# %%
df.new_path.to_list()[-1],df.img_dir.to_list()[-1]
# Out:
# ('./methane_224_data/smallsize224/val_images/val_images/41.80915275834123_-72.5911605196028/naip.png',
#  'F:\\\\CNOOC_testing\\\\Methane_dataset\\\\METHANE_PROJECT\\\\smallsize224_val\\\\val_images\\\\val_images\\41.80915275834123_-72.5911605196028\\naip.png')

# %%
df_train = df.loc[df['dataset'] == "train"]

# %%
#change this to val (will be using validation data)
df_test = df.loc[df['dataset'] == "val"]

# %%
df_train.shape
# Out:
# (85066, 11)

# %%
df_train = df_train[(df_train.Type == 'Negative') | (df_train.Type == 'CAFOs') | (df_train.Type == 'WWTreatment')
           | (df_train.Type == 'Landfills') | (df_train.Type == 'RefineriesAndTerminals')
           | (df_train.Type == 'ProcessingPlants') | (df_train.Type == 'Mines')]

# %%
df_test = df_test[(df_test.Type == 'Negative') | (df_test.Type == 'CAFOs') | (df_test.Type == 'WWTreatment')
           | (df_test.Type == 'Landfills') | (df_test.Type == 'RefineriesAndTerminals')
           | (df_test.Type == 'ProcessingPlants') | (df_test.Type == 'Mines')]

# %%
# shuffle the dataframes in place
#df_train = df_train.sample(frac=1).reset_index(drop=True)
#df_test = df_test.sample(frac=1).reset_index(drop=True)

# %%
df_train.shape
# Out:
# (84693, 11)

# %%
df_test.shape
# Out:
# (505, 11)

# %%
df_train.Type.value_counts()
# Out:
# Type
# Negative                  34195
# CAFOs                     24934
# WWTreatment               14296
# Landfills                  3915
# RefineriesAndTerminals     3817
# ProcessingPlants           1830
# Mines                      1706
# Name: count, dtype: int64

# %%
#def sampling_k_elements(group, k=1600):
#    if len(group) < k:
#        return group
#    return group.sample(k)
#balanced = df_train.groupby('Type').apply(sampling_k_elements).reset_index(drop=True)

# %%
SEED = 42
CATEGORIES = 6
TRAIN_BATCH_SIZE = 32
VAL_SPLIT = 0.2

IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNEL = 3

# %%
val_data, train_data = np.split(df_train, [int(VAL_SPLIT*len(df_train))])

# %%
val_data.shape, train_data.shape
# Out:
# ((16938, 11), (67755, 11))

# %%
class MyDataFrameIterator(image.DataFrameIterator):
    
    def __getitem__(self, idx):
        X_, y_ = super().__getitem__(idx)
        y_ = np.delete(y_, self.class_indices['Negative'], axis=1)
        return X_, y_
    
    def next(self):
        X_, y_ = super().next()
        y_ = np.delete(y_, self.class_indices['Negative'], axis=1)
        return X_, y_
    
class MyImageDataGenerator(image.ImageDataGenerator):
    
    def flow_from_dataframe(self, df, directory, *args, **kwargs):
        return MyDataFrameIterator(df, directory, *args, **kwargs)

# %%
datagen=MyImageDataGenerator(rescale=1./255,
                             #validation_split = VAL_SPLIT, # do not use this one :)
                             rotation_range=20,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True
                            )

# %%
train_gen = datagen.flow_from_dataframe(
    train_data,
    "",
    x_col="new_path",
    y_col="Type",
    color_mode='rgb',
    seed = SEED,
    class_mode="categorical",
    validate_filenames=False,
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    batch_size=TRAIN_BATCH_SIZE)
# Out:
# Found 67755 non-validated image filenames belonging to 7 classes.

# %%
val_gen = datagen.flow_from_dataframe(
    val_data,
    "",
    x_col="new_path",
    y_col="Type",
    color_mode='rgb',
    seed = SEED,
    class_mode="categorical",
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    validate_filenames=False,
    batch_size=TRAIN_BATCH_SIZE)
# Out:
# Found 16938 non-validated image filenames belonging to 7 classes.

# %%
TEST_BATCH_SIZE = 500

test_gen = datagen.flow_from_dataframe(
    df_test,
    "",
    x_col = "new_path",
    y_col = "Type",
    color_mode = 'rgb',
    seed = SEED,
    class_mode = "categorical",
    validate_filenames=False,
    target_size=(IMG_HEIGHT,IMG_WIDTH),
    batch_size=TEST_BATCH_SIZE)
# Out:
# Found 505 non-validated image filenames belonging to 7 classes.

# %%
assert train_gen.class_indices == test_gen.class_indices
assert train_gen.class_indices == val_gen.class_indices

# %%
STEP_SIZE_TRAIN = train_gen.n//train_gen.batch_size
STEP_SIZE_VALID = val_gen.n//val_gen.batch_size

# %%
def build_model():
    
    LR = 0.0005 # learning rate parameter for Adam
    
    # build network
    inp = layers.Input(shape=(224, 224, 3))
    # densenet
    dnet_core = tf.keras.applications.DenseNet121(include_top=False,
                                                  weights='imagenet',
                                                  pooling='max')

    # freeze most layers, let only last block be trainable
    for l in dnet_core.layers[:-19]:
        l.trainable = False
    x = dnet_core(inp)
    x = layers.Dense(16, activation='relu')(x)
    out = layers.Dense(CATEGORIES, activation='sigmoid')(x)
    model = Model(inputs=inp, outputs=out)
    
    loss = tf.keras.losses.BinaryCrossentropy()
    model.compile(loss=loss,
                  optimizer=Adam(learning_rate=LR),
                  metrics=[
                      tf.keras.metrics.AUC(name='auc'),
                      tf.keras.metrics.AUC(name='pr_auc', curve='PR'),
                      tf.keras.metrics.Precision(name='precision'),
                      tf.keras.metrics.Recall(name='recall'),
                      'accuracy'
                      ])
    return model

# %%
backend.clear_session()
model = build_model()
model.class_indices_ = train_gen.class_indices
model.summary()
# Out:
# 2023-05-29 13:55:23.372644: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet121 (Functional)    (None, 1024)              7037504
#
#  dense (Dense)               (None, 16)                16400
#
#  dense_1 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 7,054,006
# Trainable params: 383,414
# Non-trainable params: 6,670,592
# _________________________________________________________________

# %%
# Remember to change the run number so that we do not overwrite the
# saved model

RUN_NUMBER = 4
MODEL_NAME = f'model_v{RUN_NUMBER}_lr_0005_19_layers.hdf5'

history_cb = tf.keras.callbacks.CSVLogger(f'./{MODEL_NAME}_lr_0005_19_layers_log.csv', separator=",", append=False)
cb = [callbacks.EarlyStopping(patience=6,restore_best_weights=True),
      callbacks.ReduceLROnPlateau(patience=4),
      callbacks.ModelCheckpoint(MODEL_NAME,
                                monitor='loss',
                                verbose=1,
                                save_best_only=True),
      history_cb
      ]

# check the first epochs, if the metrics go to zero
# restart the run with slightly different hyperparameter

epochs = 30

history = model.fit_generator(generator = train_gen,
                              steps_per_epoch = STEP_SIZE_TRAIN,
                              validation_data = val_gen,
                              validation_steps = STEP_SIZE_VALID,
                              epochs = epochs,
                              callbacks = cb)
# Out:
# /tmp/ipykernel_3614/4066803107.py:22: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(generator = train_gen,
# Epoch 1/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.1754 - auc: 0.9180 - pr_auc: 0.7192 - precision: 0.7720 - recall: 0.5423 - accuracy: 0.5266
# Epoch 1: loss improved from inf to 0.17539, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1422s 664ms/step - loss: 0.1754 - auc: 0.9180 - pr_auc: 0.7192 - precision: 0.7720 - recall: 0.5423 - accuracy: 0.5266 - val_loss: 0.1327 - val_auc: 0.9536 - val_pr_auc: 0.8222 - val_precision: 0.8660 - val_recall: 0.6232 - val_accuracy: 0.5329 - lr: 5.0000e-04
# Epoch 2/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.1318 - auc: 0.9542 - pr_auc: 0.8227 - precision: 0.8405 - recall: 0.6483 - accuracy: 0.5526
# Epoch 2: loss improved from 0.17539 to 0.13183, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1329s 628ms/step - loss: 0.1318 - auc: 0.9542 - pr_auc: 0.8227 - precision: 0.8405 - recall: 0.6483 - accuracy: 0.5526 - val_loss: 0.1215 - val_auc: 0.9604 - val_pr_auc: 0.8477 - val_precision: 0.8693 - val_recall: 0.6750 - val_accuracy: 0.5697 - lr: 5.0000e-04
# Epoch 3/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.1154 - auc: 0.9649 - pr_auc: 0.8579 - precision: 0.8630 - recall: 0.6987 - accuracy: 0.5676
# Epoch 3: loss improved from 0.13183 to 0.11537, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1374s 649ms/step - loss: 0.1154 - auc: 0.9649 - pr_auc: 0.8579 - precision: 0.8630 - recall: 0.6987 - accuracy: 0.5676 - val_loss: 0.1262 - val_auc: 0.9597 - val_pr_auc: 0.8370 - val_precision: 0.8187 - val_recall: 0.6980 - val_accuracy: 0.5468 - lr: 5.0000e-04
# Epoch 4/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.1036 - auc: 0.9724 - pr_auc: 0.8808 - precision: 0.8738 - recall: 0.7291 - accuracy: 0.5742
# Epoch 4: loss improved from 0.11537 to 0.10359, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1399s 661ms/step - loss: 0.1036 - auc: 0.9724 - pr_auc: 0.8808 - precision: 0.8738 - recall: 0.7291 - accuracy: 0.5742 - val_loss: 0.1149 - val_auc: 0.9647 - val_pr_auc: 0.8619 - val_precision: 0.8449 - val_recall: 0.7203 - val_accuracy: 0.5629 - lr: 5.0000e-04
# Epoch 5/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.0920 - auc: 0.9784 - pr_auc: 0.9027 - precision: 0.8875 - recall: 0.7629 - accuracy: 0.5840
# Epoch 5: loss improved from 0.10359 to 0.09199, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1379s 649ms/step - loss: 0.0920 - auc: 0.9784 - pr_auc: 0.9027 - precision: 0.8875 - recall: 0.7629 - accuracy: 0.5840 - val_loss: 0.1223 - val_auc: 0.9601 - val_pr_auc: 0.8502 - val_precision: 0.8632 - val_recall: 0.6870 - val_accuracy: 0.5916 - lr: 5.0000e-04
# Epoch 6/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.0822 - auc: 0.9830 - pr_auc: 0.9197 - precision: 0.8977 - recall: 0.7886 - accuracy: 0.5941
# Epoch 6: loss improved from 0.09199 to 0.08217, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1332s 629ms/step - loss: 0.0822 - auc: 0.9830 - pr_auc: 0.9197 - precision: 0.8977 - recall: 0.7886 - accuracy: 0.5941 - val_loss: 0.1213 - val_auc: 0.9618 - val_pr_auc: 0.8565 - val_precision: 0.8224 - val_recall: 0.7301 - val_accuracy: 0.5480 - lr: 5.0000e-04
# Epoch 7/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.0714 - auc: 0.9875 - pr_auc: 0.9372 - precision: 0.9101 - recall: 0.8180 - accuracy: 0.6045
# Epoch 7: loss improved from 0.08217 to 0.07145, saving model to model_v4_lr_0005_19_layers.hdf5
# 2117/2117 [==============================] - 1313s 620ms/step - loss: 0.0714 - auc: 0.9875 - pr_auc: 0.9372 - precision: 0.9101 - recall: 0.8180 - accuracy: 0.6045 - val_loss: 0.1271 - val_auc: 0.9597 - val_pr_auc: 0.8509 - val_precision: 0.8078 - val_recall: 0.7315 - val_accuracy: 0.5380 - lr: 5.0000e-04
# Epoch 8/30
# 2117/2117 [==============================] - ETA: 0s - loss: 0.0627 - auc: 0.9903 - pr_auc: 0.9500 - precision: 0.9201 - recall: 0.8413 - accuracy: 0.6124

# %%
show_history(history)
plot_history(history, path="standard_v4.png")
plt.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 show_history(history)
#       2 plot_history(history, path="standard_v4.png")
#       3 plt.close()
#
# NameError: name 'history' is not defined

# %% [markdown]
# # Evaluate Model

# %%
cat_names = list(test_gen.class_indices.keys())
cat_names.remove('Negative')
cat_names
# Out:
# ['CAFOs',
#  'Landfills',
#  'Mines',
#  'ProcessingPlants',
#  'RefineriesAndTerminals',
#  'WWTreatment']

# %%
X_test, y_test = test_gen.next()
y_pred_proba = model.predict(X_test)
# Out:
# 16/16 [==============================] - 10s 482ms/step

# %%
# Use that if you want to save the arrays
#np.save(f'y_pred_proba_{RUN_NUMBER}.npy', y_pred_proba)
#np.save(f'y_test_{RUN_NUMBER}.npy', y_test)

# %% [markdown]
# ## Plot the distribution of a few predictions

# %%
plt.imshow(y_pred_proba[:20].T)
plt.colorbar()
plt.show()

# %%
plt.imshow(y_test[:20].T)
plt.colorbar()
plt.show()

# %%
# Plot a sample image from the test set
abc = X_test[0,:,:,:].reshape(224, 224, 3).astype(np.uint8)
plt.imshow(abc)
plt.colorbar()
plt.show()

# %% [markdown]
# ## Evaluate metrics

# %%
# Instantiate metrics
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
auc = tf.keras.metrics.AUC()
pr_auc = tf.keras.metrics.AUC(name='pr_auc', curve='PR')
accuracy = tf.keras.metrics.Accuracy()

# %%
# Binarize predictions
y_pred = (y_pred_proba> 0.5).astype(int)

# %%
prec_cat = {}
recall_cat = {}
auc_cat = {}
pr_auc_cat = {}
accuracy_cat = {}
overall_cat = {}

def calc_metric(y_test, y_pred, m_dict, m_fun, idx, name):
    m_dict[name] = m_fun(y_test[:][:,idx].reshape(TEST_BATCH_SIZE,1), y_pred[:][:,idx].reshape(TEST_BATCH_SIZE,1)).numpy()

dicts = [prec_cat, recall_cat, auc_cat, pr_auc_cat, accuracy_cat]
funcs = [precision, recall, auc, pr_auc, accuracy]

for idx, name in enumerate(cat_names):
    for m_dict, m_fun in zip(dicts, funcs):
        calc_metric(y_test, y_pred, m_dict, m_fun, idx, name)
    overall_cat[name] = np.mean([d[name] for d in dicts])

# %%
metrics_df = pd.DataFrame({
    'Category': cat_names,
    'Precision': list(prec_cat.values()),
    'Recall': list(recall_cat.values()),
    'AUC': list(auc_cat.values()),
    'PR AUC': list(pr_auc_cat.values()),
    'Accuracy': list(accuracy_cat.values()),
    'Overall': list(overall_cat.values())
})

print(metrics_df)
# Out:
#                  Category  Precision    Recall       AUC    PR AUC  Accuracy
# 0                   CAFOs   0.816326  0.851064  0.915598  0.727157  0.968000  \
# 1               Landfills   0.792453  0.466667  0.727289  0.461882  0.941000
# 2                   Mines   0.771930  0.341085  0.665802  0.362797  0.934667
# 3        ProcessingPlants   0.771930  0.265060  0.628986  0.305151  0.932500
# 4  RefineriesAndTerminals   0.765306  0.347222  0.668576  0.365006  0.934400
# 5             WWTreatment   0.575758  0.372549  0.673524  0.304915  0.923333
#
#     Overall
# 0  0.855629
# 1  0.677858
# 2  0.615256
# 3  0.580725
# 4  0.616102
# 5  0.570016

# %%
df_4=pd.read_csv("model_v4_lr_0005_19_layers.hdf5_lr_0005_19_layers_log.csv")
df_4[['loss', 'val_loss']].plot()
# Out:
# <Axes: >
